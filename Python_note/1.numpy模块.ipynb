# %% [markdown]
# ![log.jpg](attachment:log.jpg)

# %% [markdown]
# # 数据处理三剑客
# - numpy
# - pandas(重点)
# - matplotlib

# %% [markdown]
# ### numpy模块
# - NumPy(Numerical Python)是Python中用于数据分析、机器学习、科学计算的重要软件包，也是python进行科学计算重要基础库之一，多用于在大型、多维数组上执行的数值运算。python的不少数据处理的模块依赖于NumPy作为其基础架构的核心部分（例如scikit-learn、SciPy、pandas和tensorflow）。掌握numpy可以使得开发者在使用各数据处理库调试和处理复杂用例时更具优势。

# %% [markdown]
# - 简单理解：可以将numpy当做是一个一维或者多维的数组，并且大多数的时候，数组存储的是数值型数据。

# %% [markdown]
# #### numpy的创建
# - 使用np.array()创建
# - 使用plt创建
# - 使用np的routines函数创建

# %% [markdown]
# - 使用array()创建一个一维数组

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5])
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# - 使用array()创建一个多维数组

# %%
arr2 = np.array([[1,2,3],[4,5,6]])
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# - 数组和列表的区别是什么？
#     - 数据类型上
#         - 数组只可以存储同类型的数据
#         - 列表可以存储不同类型的数据
#             - str > float > int
#     - 运算效率上
#         - 数组会更快与列表

# %%
arr = np.array([1,'two',3.3])
arr
# Out:
# array(['1', 'two', '3.3'], dtype='<U32')

# %% [markdown]
# - 使用plt创建
#     - 将外部的一张图片读取加载到numpy数组中，然后尝试改变数组元素的数值查看对原始图片的影响

# %%
import matplotlib.pyplot as plt

# %%
ret = plt.imread('123.jpg')
ret
# Out:
# array([[[184, 227, 155],
#         [140, 187, 107],
#         [ 98, 142,  89],
#         ...,
#         [ 84, 108,  74],
#         [ 76, 100,  68],
#         [ 79,  95,  68]],
#
#        [[172, 216, 141],
#         [138, 188, 103],
#         [ 93, 138,  81],
#         ...,
#         [ 56,  81,  49],
#         [ 54,  79,  49],
#         [ 61,  81,  54]],
#
#        [[168, 212, 133],
#         [133, 183,  96],
#         [ 79, 127,  67],
#         ...,
#         [ 41,  66,  36],
#         [ 39,  65,  38],
#         [ 59,  82,  56]],
#
#        ...,
#
#        [[108, 157,  78],
#         [ 88, 151,  36],
#         [ 73, 146,  12],
#         ...,
#         [160, 185, 146],
#         [155, 186, 145],
#         [126, 161, 121]],
#
#        [[104, 154,  39],
#         [ 90, 151,  22],
#         [ 82, 153,  15],
#         ...,
#         [ 72,  89,  71],
#         [126, 155, 124],
#         [161, 199, 150]],
#
#        [[147, 190, 108],
#         [134, 185,  93],
#         [125, 181,  80],
# ...

# %%
plt.imshow(ret)

# %% [markdown]
# - linespace()
# - arange()
# - random系列

# %%
a1 = np.linspace(1,20,num=10)
a1 #返回一个等差数列
# Out:
# array([ 1.        ,  3.11111111,  5.22222222,  7.33333333,  9.44444444,
#        11.55555556, 13.66666667, 15.77777778, 17.88888889, 20.        ])

# %%
a2 = np.arange(1,10,2)
a2 #返回一个等差数列
# Out:
# array([1, 3, 5, 7, 9])

# %%
a3 = np.random.randint(0,100,size=(4,5))
a3
# Out:
# array([[56, 21, 50, 82, 57],
#        [71, 88,  7, 45, 15],
#        [32, 57,  6,  5, 89],
#        [10, 77, 76, 42, 62]])

# %% [markdown]
# #### numpy的常用属性
# - shape
# - ndim
# - size
# - dtype

# %%
a3.shape #返回数组的形状
a3.ndim #返回数组的维度
a3.size #返回数组元素个数
a3.dtype #返回数组元素的类型
# Out:
# dtype('int64')

# %% [markdown]
# #### numpy的数据类型
# - array(dtype=?):可以设定数据类型
# - arr.astype('?') :可以修改数据类型

# %%
#修改数组元素的数据类型
    #方式1：在创建数组的时候，指定元素的数据类型
a1 = np.array([1,2,3,4,5],dtype='int8')
a1.dtype
# Out:
# dtype('int8')

# %%
#方式2:修改已经存在的数组的元素的数据类型(重点)
a1 = a1.astype('float16')
a1
# Out:
# array([1., 2., 3., 4., 5.], dtype=float16)

# %% [markdown]
# - 修改数组元素的数据类型可以帮助数组瘦身（减少内存占用）
#     - nbytes可以查看数组所占内存空间的字节数

# %%
#加载外部文件数据到numpy数组中./data/CDNOW_master.txt
data = np.loadtxt('./data/CDNOW_master.txt')
data.shape
# Out:
# (69659, 4)

# %%
data.nbytes // 1024  #kb
# Out:
# 2176

# %%
data = data.astype('int8')

# %%
data.nbytes // 1024  #kb
# Out:
# 272

# %% [markdown]
# #### numpy的索引和切片操作（重点）

# %% [markdown]
# - 索引操作和列表同理
# - 作用：可以将数组中指定的数组进行提取或修改

# %%
arr = np.random.randint(0,100,size=(5,7))
arr
# Out:
# array([[71, 17, 35, 86, 43, 64, 12],
#        [78, 22, 29, 35, 74, 82, 74],
#        [39, 44, 95, 60, 86, 95, 63],
#        [34, 66, 92, 65, 21, 44, 57],
#        [44, 84, 32, 52, 51, 60, 46]])

# %%
#索引取单行：
arr[0]
# Out:
# array([71, 17, 35, 86, 43, 64, 12])

# %%
#索引取多行：
arr[[1,3]]
# Out:
# array([[78, 22, 29, 35, 74, 82, 74],
#        [34, 66, 92, 65, 21, 44, 57]])

# %%
#索引取单列：
arr[:,0]
# Out:
# array([71, 78, 39, 34, 44])

# %%
#索引取多列：
arr[:,[0,2]]
# Out:
# array([[71, 35],
#        [78, 29],
#        [39, 95],
#        [34, 92],
#        [44, 32]])

# %%
#索引取单个元素:
arr[0,1]
# Out:
# 17

# %% [markdown]
# - 切片操作
#     - 切出前两列数据
#     - 切出前两行数据
#     - 切出前两行的前两列的数据
#     - 数组数据翻转
#     - 练习：将一张图片上下左右进行翻转操作
#     - 练习：将图片进行指定区域的裁剪

# %%
arr
# Out:
# array([[71, 17, 35, 86, 43, 64, 12],
#        [78, 22, 29, 35, 74, 82, 74],
#        [39, 44, 95, 60, 86, 95, 63],
#        [34, 66, 92, 65, 21, 44, 57],
#        [44, 84, 32, 52, 51, 60, 46]])

# %%
#切行
arr[0:3]
# Out:
# array([[71, 17, 35, 86, 43, 64, 12],
#        [78, 22, 29, 35, 74, 82, 74],
#        [39, 44, 95, 60, 86, 95, 63]])

# %%
#切列
arr[:,0:3]
# Out:
# array([[71, 17, 35],
#        [78, 22, 29],
#        [39, 44, 95],
#        [34, 66, 92],
#        [44, 84, 32]])

# %%
#列倒置
arr[:,::-1]
# Out:
# array([[12, 64, 43, 86, 35, 17, 71],
#        [74, 82, 74, 35, 29, 22, 78],
#        [63, 95, 86, 60, 95, 44, 39],
#        [57, 44, 21, 65, 92, 66, 34],
#        [46, 60, 51, 52, 32, 84, 44]])

# %%
#行倒置
arr[::-1,:]
# Out:
# array([[44, 84, 32, 52, 51, 60, 46],
#        [34, 66, 92, 65, 21, 44, 57],
#        [39, 44, 95, 60, 86, 95, 63],
#        [78, 22, 29, 35, 74, 82, 74],
#        [71, 17, 35, 86, 43, 64, 12]])

# %%
#将图片进行左右翻转
img_arr = plt.imread('123.jpg')
plt.imshow(img_arr)

# %%
img_arr.shape #前两个维度是像素，第三个维度是颜色通道
# Out:
# (751, 751, 3)

# %%
plt.imshow(img_arr[:,::-1,:])

# %%
plt.imshow(img_arr[::-1,:,:])

# %%
#将熊猫头部进行裁剪
plt.imshow(img_arr[180:450,200:400,:])

# %% [markdown]
# #### 变形reshape(重点)
# - 注意：变形前和变形后数组的容量不可以发生变化

# %%
a1 = np.random.randint(0,100,size=(5,6))
a1
# Out:
# array([[35, 34, 12,  7, 60, 35],
#        [34, 29, 64, 16, 84,  2],
#        [97, 56, 43, 12, 43, 25],
#        [64, 59, 81, 94,  4, 63],
#        [ 7, 67, 57, 43, 89, 76]])

# %%
#将a1进行变形
a1.reshape((2,15))
# Out:
# array([[35, 34, 12,  7, 60, 35, 34, 29, 64, 16, 84,  2, 97, 56, 43],
#        [12, 43, 25, 64, 59, 81, 94,  4, 63,  7, 67, 57, 43, 89, 76]])

# %%
a1.reshape((2,3,5))
# Out:
# array([[[35, 34, 12,  7, 60],
#         [35, 34, 29, 64, 16],
#         [84,  2, 97, 56, 43]],
#
#        [[12, 43, 25, 64, 59],
#         [81, 94,  4, 63,  7],
#         [67, 57, 43, 89, 76]]])

# %% [markdown]
# #### 级联操作(重点)
#     - 将多个numpy数组进行横向或者纵向的拼接
# - axis轴向的理解
#     - 0:列
#     - 1:行
# - 问题：
#     - 级联的两个数组维度一样，但是行列个数不一样会如何？

# %%
a1 = np.random.randint(0,100,size=(3,5))
a2 = np.random.randint(0,100,size=(3,6))

# %%
np.concatenate((a1,a2),axis=1) #行跟行进行级联
# Out:
# array([[69, 99, 14, 31, 93, 14, 73, 38, 57,  5, 73],
#        [62, 42, 59, 74, 72, 14, 22, 33, 98, 46, 55],
#        [45, 80, 68, 45, 19, 33, 59, 36, 80, 58, 28]])

# %%
np.concatenate((a1,a2),axis=0) #列跟列进行级联
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 np.concatenate((a1,a2),axis=0)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 5 and the array at index 1 has size 6

# %%
#照片的9宫格
img_arr = plt.imread('123.jpg')
img_3 = np.concatenate((img_arr,img_arr,img_arr),axis=1)
img_9 = np.concatenate((img_3,img_3,img_3),axis=0)
plt.imshow(img_9)

# %% [markdown]
# #### 常用的聚合操作（重点）
# - sum(求和),max（求最大值）,min（求最小值）,mean（求均值），count(求元素个数)

# %%
arr = np.random.randint(0,20,size=(5,6))
arr
# Out:
# array([[ 2,  8,  4,  8, 12, 14],
#        [ 4,  9,  1,  4, 19,  4],
#        [16,  4, 13, 19,  7,  4],
#        [10,  6, 10,  2, 12, 10],
#        [19,  3, 12,  4,  8, 15]])

# %%
arr.mean()  #求所有元素的均值
# Out:
# 8.766666666666667

# %%
arr.mean(axis=1) #求出了每一行的均值
# Out:
# array([ 8.        ,  6.83333333, 10.5       ,  8.33333333, 10.16666667])

# %% [markdown]
# #### 常用的数学函数
# ![image.png](attachment:image.png)

# %%
np.log2(arr)
# Out:
# array([[1.        , 3.        , 2.        , 3.        , 3.5849625 ,
#         3.80735492],
#        [2.        , 3.169925  , 0.        , 2.        , 4.24792751,
#         2.        ],
#        [4.        , 2.        , 3.70043972, 4.24792751, 2.80735492,
#         2.        ],
#        [3.32192809, 2.5849625 , 3.32192809, 1.        , 3.5849625 ,
#         3.32192809],
#        [4.24792751, 1.5849625 , 3.5849625 , 2.        , 3.        ,
#         3.9068906 ]])

# %% [markdown]
# #### 常用的统计函数（重点）
# - numpy.median() 函数用于计算数组 a 中元素的中位数（中值）
# - 标准差std():标准差是一组数据平均值分散程度的一种度量。
#     - 公式：std = sqrt(mean((x - x.mean())**2))
#     - 如果数组是 [1，2，3，4]，则其平均值为 2.5。 因此，差的平方是 [2.25,0.25,0.25,2.25]，并且其平均值的平方根除以 4，即 sqrt(5/4) ，结果为 1.1180339887498949。
# - 方差var()：统计中的方差（样本方差）是每个样本值与全体样本值的平均数之差的平方值的平均数，即 mean((x - x.mean())** 2)。换句话说，标准差是方差的平方根。
# - argmax():求出数组中最大元素下标

# %%
np.median(arr,axis=0)
# Out:
# array([10.,  6., 10.,  4., 12., 10.])

# %%
arr.std(axis=1)
# Out:
# array([4.163332  , 5.92780641, 5.85234996, 3.34995854, 5.75663868])
